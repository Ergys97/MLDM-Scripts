# %% [markdown]
# <a href="https://colab.research.google.com/github/Ergys97/MLDM-Scripts/blob/main/Python-Introduction/04-Matplotlib-Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Practice - Hints - Unibs 2021

# %% [markdown]
# ### Import matplotlib.pyplot package under name `plt` and print version
# `hint: import ... as, plt.__version__ `

# %%
import matplotlib
import matplotlib.pyplot as plt

print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# ### Activate matplotlib inline
# `hint: ... inline`

# %%
# %matplotlib inline

# %% [markdown]
# ## Base

# %% [markdown]
# ### Plot a line with formula $y = 2x + 1$
# `hint: np.arange, plt.figure, plt.plot, plt.title, plt.xlabel, plt.ylabel, plt.grid, plt.legend, plt.show`
#
# - Use points in range [1, 20]
# - Figure size of (10,5)
# - Set axis labels
# - Set plot title
# - Set line color as red
# - Discontinued line (--) with star (\*) on point
# - Plot the legend with the formula in latex version (`r"$ ... $"`)
# - Set a dashed grid

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1, 21)
y = 2 * x + 1

plt.figure(figsize=(10, 5))
plt.plot(x, y, 'r*--', label=r'$y = 2x + 1$')
plt.title('Plot of y = 2x + 1')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# ### Add to the previous plot the line with formula $y = log(x) + 1$ in the same range
# `hint: np.log, plt.plot`
#
# - Set line color as blue
# - Normal line (-) with square (s) char on point

# %%
y_log = np.log(x) + 1

plt.figure(figsize=(10, 5))
plt.plot(x, y, 'r*--', label=r'$y = 2x + 1$')
plt.plot(x, y_log, 'bs-', label=r'$y = \log(x) + 1$')
plt.title('Plot of y = 2x + 1 and y = log(x) + 1')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# ### Add to the previous plot the line with formula $y=x^2 - 1$ in the same range
# `hint: x**2, plt.plot`
#
# - Set line color as green
# - Normal line (-) with + (plus) char on point

# %%
y_square = x**2 - 1

plt.figure(figsize=(10, 5))
plt.plot(x, y, 'r*--', label=r'$y = 2x + 1$')
plt.plot(x, y_log, 'bs-', label=r'$y = \log(x) + 1$')
plt.plot(x, y_square, 'g+-', label=r'$y = x^2 - 1$')
plt.title('Plot of y = 2x + 1, y = log(x) + 1 and y = x^2 - 1')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# ### Replot the previous plot in different subplots in the same line without sharing axes
# `hint: plt.subplots, axes[].plot, axes[].set_title, axes[].set_xlabel, axes[].set_ylabel, axes[].grid, axes[].legend, fig.tight_layout`

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].plot(x, y, 'r*--', label=r'$y = 2x + 1$')
axes[0].set_title(r'$y = 2x + 1$')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].grid(True, linestyle='--')
axes[0].legend()

axes[1].plot(x, y_log, 'bs-', label=r'$y = \log(x) + 1$')
axes[1].set_title(r'$y = \log(x) + 1$')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')
axes[1].grid(True, linestyle='--')
axes[1].legend()

axes[2].plot(x, y_square, 'g+-', label=r'$y = x^2 - 1$')
axes[2].set_title(r'$y = x^2 - 1$')
axes[2].set_xlabel('x')
axes[2].set_ylabel('y')
axes[2].grid(True, linestyle='--')
axes[2].legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Replot the previous plot sharing y between suplots
# `hint: sharey=True`

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

axes[0].plot(x, y, 'r*--', label=r'$y = 2x + 1$')
axes[0].set_title(r'$y = 2x + 1$')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].grid(True, linestyle='--')
axes[0].legend()

axes[1].plot(x, y_log, 'bs-', label=r'$y = \log(x) + 1$')
axes[1].set_title(r'$y = \log(x) + 1$')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')
axes[1].grid(True, linestyle='--')
axes[1].legend()

axes[2].plot(x, y_square, 'g+-', label=r'$y = x^2 - 1$')
axes[2].set_title(r'$y = x^2 - 1$')
axes[2].set_xlabel('x')
axes[2].set_ylabel('y')
axes[2].grid(True, linestyle='--')
axes[2].legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Replot the previous plot using the for loop, lists and dictionaries
# `hint: functions = [...], {"title": ..., "y": ..., "label": ..., "linestyle": ...}, zip(functions, axes)`

# %%
functions = [
    {"title": r'$y = 2x + 1$', "y": y, "label": r'$y = 2x + 1$', "linestyle": 'r*--'},
    {"title": r'$y = \log(x) + 1$', "y": y_log, "label": r'$y = \log(x) + 1$', "linestyle": 'bs-'},
    {"title": r'$y = x^2 - 1$', "y": y_square, "label": r'$y = x^2 - 1$', "linestyle": 'g+-'}
]

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

for func, ax in zip(functions, axes):
    ax.plot(x, func["y"], func["linestyle"], label=func["label"])
    ax.set_title(func["title"])
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.grid(True, linestyle='--')
    ax.legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Plot functions $ y_i = i\cdot x - 5i$ with $i$ in range (0, 10) in the same plot with size (10,5) and a different color for each function

# %%
fig, ax = plt.subplots(figsize=(10, 5))

colors = plt.cm.viridis(np.linspace(0, 1, 10))

for i, color in enumerate(colors):
    y_i = i * x - 5 * i
    ax.plot(x, y_i, label=f'$y_{i} = {i} \cdot x - 5{i}$', color=color)

ax.set_title('Plot of $y_i = i \cdot x - 5i$')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.grid(True, linestyle='--')
ax.legend()
plt.show()

# %% [markdown]
# ### Plot functions $ y_i = i\cdot x - 5i$ with $i$ in range (0, 10) in different subplots with shared y and figure size (20,5)

# %%
fig, axes = plt.subplots(1, 10, figsize=(20, 5), sharey=True)

colors = plt.cm.viridis(np.linspace(0, 1, 10))

for i, (ax, color) in enumerate(zip(axes, colors)):
    y_i = i * x - 5 * i
    ax.plot(x, y_i, label=f'$y_{i} = {i} \cdot x - 5i$', color=color)
    ax.set_title(f'$y_{i}$')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.grid(True, linestyle='--')
    ax.legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Intermediate

# %% [markdown]
# ### Plot a red scatterplot of $x$ squared
# `hint: plt.scatter`

# %%
y_square = x**2

plt.scatter(x, y_square, color='red')
plt.title('Scatter plot of $x^2$')
plt.xlabel('x')
plt.ylabel('$x^2$')
plt.show()

# %% [markdown]
# ### Plot a blue step plot of $x$ squared with linewidth of $3$
# `hint: plt.step`

# %%
plt.step(x, y_square, color='blue', linewidth=3)
plt.title('Step plot of $x^2$')
plt.xlabel('x')
plt.ylabel('$x^2$')
plt.show()

# %% [markdown]
# ### Plot an orange barplot plot of $x$ squared with alpha of $0.25$
# `hint: plt.bar`

# %%
plt.bar(x, y_square, color='orange', alpha=0.25)
plt.title('Bar plot of $x^2$')
plt.xlabel('x')
plt.ylabel('$x^2$')
plt.show()

# %% [markdown]
# ### Plot the area between $x$ squared and the $x \cdot log(x)$ function in green and alpha $0.5$
# `hint: plt.fill_between`

# %%
y_log_x = x * np.log(x)

plt.fill_between(x, y_square, y_log_x, color='green', alpha=0.5)
plt.title('Area between $x^2$ and $x \cdot \log(x)$')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Replot previous plots in square grid (2,2)
# `hint: axes[][]`

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

axes[0, 0].scatter(x, y_square, color='red')
axes[0, 0].set_title('Scatter plot of $x^2$')
axes[0, 0].set_xlabel('x')
axes[0, 0].set_ylabel('$x^2$')

axes[0, 1].step(x, y_square, color='blue', linewidth=3)
axes[0, 1].set_title('Step plot of $x^2$')
axes[0, 1].set_xlabel('x')
axes[0, 1].set_ylabel('$x^2$')

axes[1, 0].bar(x, y_square, color='orange', alpha=0.25)
axes[1, 0].set_title('Bar plot of $x^2$')
axes[1, 0].set_xlabel('x')
axes[1, 0].set_ylabel('$x^2$')

axes[1, 1].fill_between(x, y_square, y_log_x, color='green', alpha=0.5)
axes[1, 1].set_title('Area between $x^2$ and $x \cdot \log(x)$')
axes[1, 1].set_xlabel('x')
axes[1, 1].set_ylabel('y')

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Plot purple histogram of 50 bins and pink cumulative instogram of 100K random samples in subplots
# `hint: np.random.randn, axes[].hist(), cumulative=True, bins=50`

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

data = np.random.randn(100000)

axes[0].hist(data, bins=50, color='purple')
axes[0].set_title('Histogram with 50 bins')

axes[1].hist(data, bins=50, cumulative=True, color='pink')
axes[1].set_title('Cumulative Histogram with 50 bins')

plt.show()
